# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#### read the csv files

# %%
df=pd.read_csv('E:\\power BI\\progects\\titanic\\train.csv')
df1=pd.read_csv('E:\\power BI\\progects\\titanic\\test.csv')
df2=pd.read_csv('E:\\power BI\\progects\\titanic\\gender.csv')

# %% [markdown]
# Explolatory Data Analysis(EDA)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df=df.drop(df.columns[[3,8,9,10]],axis=1)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0              1         0       3    male  22.0      1      0        S
# 1              2         1       1  female  38.0      1      0        C
# 2              3         1       3  female  26.0      0      0        S
# 3              4         1       1  female  35.0      1      0        S
# 4              5         0       3    male  35.0      0      0        S
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0        S
# 887          888         1       1  female  19.0      0      0        S
# 888          889         0       3  female   NaN      1      2        S
# 889          890         1       1    male  26.0      0      0        C
# 890          891         0       3    male  32.0      0      0        Q
#
# [891 rows x 8 columns]

# %%
df['Embarked'].fillna(df.Embarked.mode()[0],inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0              1         0       3    male  22.0      1      0        S
# 1              2         1       1  female  38.0      1      0        C
# 2              3         1       3  female  26.0      0      0        S
# 3              4         1       1  female  35.0      1      0        S
# 4              5         0       3    male  35.0      0      0        S
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0        S
# 887          888         1       1  female  19.0      0      0        S
# 888          889         0       3  female   NaN      1      2        S
# 889          890         1       1    male  26.0      0      0        C
# 890          891         0       3    male  32.0      0      0        Q
#
# [891 rows x 8 columns]

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.Age.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
df['Age'].fillna(29.699118,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch Embarked
# 0              1         0       3    male  22.000000      1      0        S
# 1              2         1       1  female  38.000000      1      0        C
# 2              3         1       3  female  26.000000      0      0        S
# 3              4         1       1  female  35.000000      1      0        S
# 4              5         0       3    male  35.000000      0      0        S
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0        S
# 887          888         1       1  female  19.000000      0      0        S
# 888          889         0       3  female  29.699118      1      2        S
# 889          890         1       1    male  26.000000      0      0        C
# 890          891         0       3    male  32.000000      0      0        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# data  visualization

# %%
plt.figure(figsize=(12,6))
plt.scatter('Age','Survived',data=df)
plt.title('Survived by age',fontsize=10)
plt.xlabel('Age',fontsize=10)
plt.ylabel('Survived',fontsize=10)
# Out:
# Text(0, 0.5, 'Survived')

# %%
plt.figure(figsize=(12,6))
plt.title('Distribution of age')
plt.hist(df.Age)
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
df.Sex.describe(),df.Sex.value_counts()
# Out:
# (count      891
#  unique       2
#  top       male
#  freq       577
#  Name: Sex, dtype: object,
#  male      577
#  female    314
#  Name: Sex, dtype: int64)

# %%
fig=plt.figure(figsize=(10,5))
fig.add_subplot(121)
plt.title('male vs female',fontsize=10)
plt.pie(df.Sex.value_counts(),
        autopct='%1.0f%%',
        labels=('male','female'),
        startangle=50,
        shadow=True,
        colors=['g','b'])
fig.add_subplot(122)
plt.hist(df.Sex.value_counts(),bins=5)
plt.title('Distribution of the number of males & females')
# Out:
# Text(0.5, 1.0, 'Distribution of the number of males & females')

# %%
df.Survived.value_counts()+df2.Survived.value_counts()
# Out:
# 0    815
# 1    494
# Name: Survived, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
x=df[df.Survived==0].Sex.value_counts(),df[df.Survived==1].Sex.value_counts()
x
# Out:
# (male      468
#  female     81
#  Name: Sex, dtype: int64,
#  female    233
#  male      109
#  Name: Sex, dtype: int64)

# %%
fig=plt.figure(figsize=(12,6))
fig.add_subplot(121)
colors=['DarkMagenta','Yellow']
plt.title('percent of death between male & female')
plt.pie(df[df.Survived==0].Sex.value_counts(),
        labels=('male','female'),
        autopct='%1.0f%%',
        startangle=20,
        shadow=True,
        colors=colors)
fig.add_subplot(122)
colors=['r','g']
plt.title('percent of live between male & female')
plt.pie(df[df.Survived==1].Sex.value_counts(),
        labels=('male','female'),
        autopct=('%1.0f%%'),
        startangle=20,
        shadow=True,
        colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x296b6a1af40>,
# ...
#  [Text(-0.8742242346841833, 0.6676316255921779, 'male'),
#   Text(0.8742242971923635, -0.6676315437413951, 'female')],
#  [Text(-0.47684958255500903, 0.36416270486846064, '68%'),
#   Text(0.47684961665038006, -0.36416266022257915, '32%')])

# %%
x=df.groupby('Embarked')['Survived'].count()
x
# Out:
# Embarked
# C    168
# Q     77
# S    646
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(12,6))
x.plot.bar(color=['r','b','g'])
plt.title('most port of Embarked for passenger')
# Out:
# Text(0.5, 1.0, 'most port of Embarked for passenger')

# %%
fig=plt.figure(figsize=(12,6))
fig.add_subplot(121)
plt.title('survived=0')
plt.xlabel('Embarked')
df[df.Survived==0].Embarked.value_counts().plot.bar(color=['r','g','y'])
fig.add_subplot(122)
plt.title('survived=1')
plt.xlabel('Embarked')
df[df.Survived==1].Embarked.value_counts().plot.bar(color=['r','g','y'])
# Out:
# <AxesSubplot:title={'center':'survived=1'}, xlabel='Embarked'>

# %%
df.groupby('Survived')['Age'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Age, dtype: int64

# %%
df.Age.describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
df[df['Pclass']==1].Survived.count(),df[df['Pclass']==2].Survived,df[df['Pclass']==3].Survived
# Out:
# (216,
#  9      1
#  15     1
#  17     1
#  20     0
#  21     1
#        ..
#  866    1
#  874    1
#  880    1
#  883    0
#  886    0
#  Name: Survived, Length: 184, dtype: int64,
#  0      0
#  2      1
#  4      0
#  5      0
#  7      0
#        ..
#  882    0
#  884    0
#  885    0
#  888    0
#  890    0
#  Name: Survived, Length: 491, dtype: int64)

# %%
df.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
fig=plt.figure(figsize=(12,6))
fig.add_subplot(121)
plt.title('how does Pclass affect the survived rate(the live)')
plt.xlabel('Pclass')
df[df['Survived']==1].Pclass.value_counts().plot.bar(color=['b','r','y'])

fig.add_subplot(122)
plt.title('how does Pclass affect the survived rate(the death)')
plt.xlabel('Pclass')
df[df['Survived']==0].Pclass.value_counts().plot.bar(color=['b','r','y'])
# Out:
# <AxesSubplot:title={'center':'how does Pclass affect the survived rate(the death)'}, xlabel='Pclass'>

# %%
df.groupby('SibSp')['Survived'].value_counts()
# Out:
# SibSp  Survived
# 0      0           398
#        1           210
# 1      1           112
#        0            97
# 2      0            15
#        1            13
# 3      0            12
#        1             4
# 4      0            15
#        1             3
# 5      0             5
# 8      0             7
# Name: Survived, dtype: int64

# %%
fig=plt.figure(figsize=(12,4))
fig.add_subplot(121)
plt.title('how does SibSp affect survived rate(the live)')
plt.xlabel('SibSp')
df[df['Survived']==1].SibSp.value_counts().plot.line()

fig.add_subplot(122)
plt.title('how does SibSp affect survived rate(the death)')
plt.xlabel('SibSp')
df[df['Survived']==0].SibSp.value_counts().plot.line()
# Out:
# <AxesSubplot:title={'center':'how does SibSp affect survived rate(the death)'}, xlabel='SibSp'>

# %%
df.groupby('Parch')['Survived'].value_counts()
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      1            65
#        0            53
# 2      0            40
#        1            40
# 3      1             3
#        0             2
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: Survived, dtype: int64

# %%
fig=plt.figure(figsize=(12,4))
fig.add_subplot(121)
plt.title('how does Parch affect survived rate(the live)')
plt.xlabel('Parch')
df[df['Survived']==1].Parch.value_counts().plot.area()

fig.add_subplot(122)
plt.title('how does Parch affect survived rate(the death)')
plt.xlabel('Parch')
df[df['Survived']==0].Parch.value_counts().plot.area()
# Out:
# <AxesSubplot:title={'center':'how does Parch affect survived rate(the death)'}, xlabel='Parch'>

# %%
df.groupby('Survived')[['SibSp','Parch']].count()
# Out:
#           SibSp  Parch
# Survived
# 0           549    549
# 1           342    342

# %%
plt.figure(figsize=(12,6))
plt.title('how does family affect the survived rate(the live)')
(df[df['Survived']==1].SibSp.value_counts()+df[df['Survived']==1].Parch.value_counts()).plot.line()
plt.xlabel('family')
# Out:
# Text(0.5, 0, 'family')

# %%
plt.figure(figsize=(12,6))
plt.title('how does family affect the survived rate(the death)')
(df[df['Survived']==0].SibSp.value_counts()+df[df['Survived']==0].Parch.value_counts()).plot.line()
plt.xlabel('family')
# Out:
# Text(0.5, 0, 'family')

# %%
sns.pairplot(df)
